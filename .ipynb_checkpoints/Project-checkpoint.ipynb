# %%
import pandas as pd
import glob
import os
from collections import Counter

# %%
path = r'C:\Users\16467\Documents\OMSA\CDA_ISYE6740_Spring24\project\data' 
all_files = glob.glob(path + "/*.csv")

# %%
#all_files

# %%
#https://stackoverflow.com/questions/56949605/how-to-read-each-file-from-a-folder-and-create-seperate-data-frames-for-each-fil
d = {os.path.splitext(os.path.basename(f))[0] : pd.read_csv(f) for f in all_files}

# %%
#create a list of tuples where each tuple is (name of csv,dataframe)

#https://stackoverflow.com/questions/10795973/python-dictionary-search-values-for-keys-using-regular-expression
ncaa_list = [(key, value) for key, value in d.items() if key.startswith("ncaa_")]

#add year column to each dataframe

for entry in ncaa_list:
    if 'year' not in entry[1].columns:
        name = entry[0][len(entry[0]) - 2:]
        year = "20"+name
        entry[1].insert(0, 'year', int(year))

#concat dfs in list into one df
ncaa_all = pd.DataFrame()
for i in ncaa_list:
    ncaa_all = pd.concat([ncaa_all,i[1]])

# %%
#do the above for NFL data

nfl_list = [(key, value) for key, value in d.items() if key.startswith("nfl_")]

for entry in nfl_list:
    if 'year' not in entry[1].columns:
        name = entry[0][len(entry[0]) - 2:]
        year = "20"+name
        entry[1].insert(0, 'year', int(year))

nfl_all = pd.DataFrame()
for i in nfl_list:
    nfl_all = pd.concat([nfl_all,i[1]])

# %%
nflWR = nfl_all.loc[nfl_all['position'] == 'WR']
ncaaWR = ncaa_all.loc[ncaa_all['position']  == 'WR']

# %%
#drop all columns that are not player and player_id
merged = pd.merge(ncaaWR, nflWR, left_on=['player','player_id'], right_on=['player','player_id'], how='inner')
columns_drop = list((Counter(list(merged.columns))-Counter(['player','player_id'])).elements())
merged.drop(columns=columns_drop, inplace=True)

#get the list of WRs who are in both the NCAA and NFL datasets
player_list = merged.drop_duplicates()

#Create separate dfs with WR players who have played in the NCCA and the NFL
ncaa = ncaaWR[ncaaWR['player_id'].isin(player_list['player_id'])]
nfl = nflWR[nflWR['player_id'].isin(player_list['player_id'])]

# %%
unique_ncaa = ncaa.drop_duplicates('player_id')
print(f"We have {len(unique_ncaa)} players who have played in both the NCAA between 2014-2022 and the NFL between 2015-2023")
# Out:
# We have 377 players who have played in both the NCAA between 2014-2022 and the NFL between 2015-2023

# %%
ncaa = ncaa.reset_index(drop=True)
nfl = nfl.reset_index(drop=True)

# %%
ncaa
# Out:
#       year              player  player_id position   team_name  \
# 0     2014        Amari Cooper       9437       WR     ALABAMA
# 1     2014        Justin Hardy       9540       WR  E CAROLINA
# 2     2014         Vince Mayle       9556       WR  WASH STATE
# 3     2014         Kevin White       9440       WR  W VIRGINIA
# 4     2014       Jaelen Strong       9503       WR  ARIZONA ST
# ...    ...                 ...        ...      ...         ...
# 1082  2022      Cedric Tillman      84434       WR   TENNESSEE
# 1083  2022        Jalen Brooks     111284       WR  S CAROLINA
# 1084  2022      Michael Wilson      84423       WR    STANFORD
# 1085  2022    Shedrick Jackson      84136       WR      AUBURN
# 1086  2022  Jaxon Smith-Njigba     129758       WR  OHIO STATE
#
#       player_game_count  avg_depth_of_target  avoided_tackles  caught_percent  \
# 0                    14                  9.9               26            71.3
# 1                    13                  9.5               20            72.5
# 2                    12                  9.8               25            65.0
# 3                    13                 11.1               24            68.1
# 4                    12                 13.9                7            53.3
# ...                 ...                  ...              ...             ...
# 1082                  6                 14.4                3            62.7
# 1083                 12                 11.4                7            71.7
# 1084                  6                 10.4                2            67.5
# 1085                 12                 14.8                0            50.0
# 1086                  3                 12.1                0            50.0
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 0                      NaN  ...               128.7      174          16
# 1                      NaN  ...               107.2      167          10
# 2                      NaN  ...               104.9      163           9
# 3                      NaN  ...               104.3      160          10
# 4                      NaN  ...                92.2      152          10
# ...                    ...  ...                 ...      ...         ...
# 1082                  42.9  ...                93.7       59           3
# 1083                  57.1  ...               105.3       46           1
# 1084                  50.0  ...               135.5       40           4
# 1085                   0.0  ...                59.0       32           0
# 1086                   0.0  ...                64.1        8           0
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 0          79.6         355   1727                878
# 1          35.1         231   1494                612
# 2          99.3         575   1483                827
# 3          90.7         535   1447                679
# 4          74.7         340   1168                421
# ...         ...         ...    ...                ...
# 1082       88.6         203    417                106
# 1083       81.7         245    499                224
# 1084       76.3         148    421                186
# 1085       91.5         237    217                 68
# 1086       12.5           5     39                 14
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 0                                 7.1                 13.9  3.99
# 1                                 5.1                 12.3  2.39
# 2                                 7.8                 14.0  2.69
# 3                                 6.2                 13.3  2.59
# 4                                 5.2                 14.4  2.71
# ...                               ...                  ...   ...
# 1082                              2.9                 11.3  2.01
# 1083                              6.8                 15.1  1.76
# 1084                              6.9                 15.6  2.30
# 1085                              4.3                 13.6  0.89
# 1086                              3.5                  9.8  0.98
#
# [1087 rows x 46 columns]

# %%
nfl
# Out:
#       year            player  player_id position team_name  player_game_count  \
# 0     2015      Amari Cooper       9437       WR       OAK                 16
# 1     2015      Stefon Diggs       9579       WR       MIN                 14
# 2     2015   Jamison Crowder       9538       WR       WAS                 17
# 3     2015     Tyler Lockett       9502       WR       SEA                 18
# 4     2015    Devin Funchess       9474       WR       CAR                 19
# ...    ...               ...        ...      ...       ...                ...
# 1112  2023     Erik Ezukanma      78148       WR       MIA                  2
# 1113  2023  D'Wayne Eskridge      29573       WR       SEA                  1
# 1114  2023    Collin Johnson      47808       WR       CHI                  3
# 1115  2023     Andy Isabella      47448       WR       BUF                  3
# 1116  2023     Cody Thompson      48152       WR       SEA                  6
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 0                    10.6               14            58.5
# 1                    11.1               13            67.5
# 2                     6.0                3            79.5
# 3                    14.8                8            74.3
# 4                    13.9                3            52.9
# ...                   ...              ...             ...
# 1112                  6.0                0             0.0
# 1113                 17.0                0             0.0
# 1114                  7.0                0           100.0
# 1115                 -7.0                0             0.0
# 1116                  7.0                0           100.0
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 0                      NaN  ...                93.2      123           6
# 1                      NaN  ...                96.8       83           4
# 2                      NaN  ...               102.9       78           2
# 3                      NaN  ...               133.5       74           7
# 4                      NaN  ...                96.8       68           6
# ...                    ...  ...                 ...      ...         ...
# 1112                   NaN  ...                39.6        1           0
# 1113                   NaN  ...                39.6        1           0
# 1114                   NaN  ...               112.5        1           0
# 1115                   NaN  ...                39.6        1           0
# 1116                   NaN  ...               108.3        1           0
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 0          82.6         502   1070                383
# 1          83.5         375    746                306
# 2          21.8         115    619                341
# 3          65.6         342    774                283
# 4          86.4         248    546                116
# ...         ...         ...    ...                ...
# 1112       50.0           7      0                  0
# 1113       85.7           6      0                  0
# 1114       60.0           9     11                  4
# 1115       62.5           5      0                  0
# 1116       85.7           6     10                  3
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 0                                 5.3                 14.9  1.84
# 1                                 5.5                 13.3  1.76
# 2                                 5.5                 10.0  1.25
# 3                                 5.1                 14.1  1.55
# 4                                 3.2                 15.2  2.01
# ...                               ...                  ...   ...
# 1112                              NaN                  NaN  0.00
# 1113                              NaN                  NaN  0.00
# 1114                              4.0                 11.0  0.79
# 1115                              NaN                  NaN  0.00
# 1116                              3.0                 10.0  1.43
#
# [1117 rows x 46 columns]

# %%
gk = ncaa.groupby('player')
for name, group in gk:
    print(name,group)
# Out:
# A.J. Brown      year      player  player_id position team_name  player_game_count  \
# 397  2016  A.J. Brown      48327       WR  OLE MISS                 12
# 478  2017  A.J. Brown      48327       WR  OLE MISS                 12
# 622  2018  A.J. Brown      48327       WR  OLE MISS                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 397                 11.7               10            67.4
# 478                  9.4               23            78.1
# 622                 11.2               17            73.0
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 397                   NaN  ...                94.3       43           2
# 478                  68.8  ...               143.9       96          11
# 622                  40.0  ...               113.2      115           6
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 397       95.4         188    412                175
# 478        0.0           0   1253                650
# 622       40.4         184   1307                600
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 397                              6.0                 14.2  2.19
# 478                              8.7                 16.7  3.19
# 622                              7.1                 15.6  3.01
#
# [3 rows x 46 columns]
# A.T. Perry       year      player  player_id position team_name  player_game_count  \
# 886   2019  A.T. Perry      77975       WR      WAKE                  4
# 956   2020  A.T. Perry      77975       WR      WAKE                  7
# 994   2021  A.T. Perry      77975       WR      WAKE                 14
# 1057  2022  A.T. Perry      77975       WR      WAKE                 13
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 886                  14.0                0            66.7
# 956                  14.2                1            47.1
# 994                  15.6               11            56.8
# 1057                 14.7                5            62.8
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 886                    NaN  ...               140.3        6           1
# 956                   40.0  ...                77.8       34           1
# 994                   36.0  ...               122.2      125          15
# 1057                  44.0  ...               102.2      129          11
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 886        86.2          25     62                  0
# 956        90.2         148    218                 43
# 994        90.3         465   1296                322
# 1057       91.2         412   1100                164
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 886                               0.0                 15.5  2.21
# 956                               2.7                 13.6  1.42
# 994                               4.5                 18.3  2.66
# 1057                              2.0                 13.6  2.57
#
# [4 rows x 46 columns]
# Aaron Burbridge      year           player  player_id position   team_name  player_game_count  \
# 89   2014  Aaron Burbridge      10847       WR  MICH STATE                 13
# 151  2015  Aaron Burbridge      10847       WR  MICH STATE                 14
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 89                  12.4                4            58.0
# 151                 12.2                7            58.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 89                    NaN  ...                86.9       50           1
# 151                   NaN  ...                96.8      146           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 89        79.8         170    358                 73
# 151       81.1         378   1258                300
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 89                               2.5                 12.3  1.80
# 151                              3.5                 14.8  2.85
#
# [2 rows x 46 columns]
# Adam Humphries      year          player  player_id position team_name  player_game_count  \
# 105  2014  Adam Humphries      10075       WR   CLEMSON                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 105                  6.2                5            73.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 105                   NaN  ...                83.7       41           0
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 105       32.3         106    203                158
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 105                              5.3                  6.8  0.64
#
# [1 rows x 46 columns]
# Alec Pierce       year       player  player_id position   team_name  player_game_count  \
# 761   2018  Alec Pierce      78038       WR  CINCINNATI                  3
# 832   2019  Alec Pierce      78038       WR  CINCINNATI                 14
# 968   2020  Alec Pierce      78038       WR  CINCINNATI                  6
# 1016  2021  Alec Pierce      78038       WR  CINCINNATI                 14
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 761                  23.0                0             0.0
# 832                  17.1                4            62.7
# 968                  15.1                0            70.8
# 1016                 17.1                4            63.4
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 761                    NaN  ...                39.6        1           0
# 832                   36.8  ...                90.9       59           2
# 968                   66.7  ...               152.8       24           3
# 1016                  46.7  ...               126.7       82           8
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 761        92.3          12      0                  0
# 832        96.9         342    657                145
# 968        80.0         108    315                 74
# 1016       84.7         321    873                190
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 761                               NaN                  NaN  0.00
# 832                               3.9                 17.8  1.95
# 968                               4.4                 18.5  2.46
# 1016                              3.7                 16.8  2.38
#
# [4 rows x 46 columns]
# Alex Erickson      year         player  player_id position  team_name  player_game_count  \
# 25   2014  Alex Erickson      11107       WR  WISCONSIN                 14
# 162  2015  Alex Erickson      11107       WR  WISCONSIN                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 25                  14.0                3            53.4
# 162                 11.7               10            60.6
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 25                    NaN  ...                67.3      103           3
# 162                   NaN  ...                79.5      127           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 25        83.8         279    772                325
# 162       48.5         192    979                275
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 25                               5.9                 14.0  2.44
# 162                              3.6                 12.7  2.59
#
# [2 rows x 46 columns]
# Allen Lazard      year        player  player_id position   team_name  player_game_count  \
# 42   2014  Allen Lazard      48135       WR  IOWA STATE                 12
# 192  2015  Allen Lazard      48135       WR  IOWA STATE                 11
# 320  2016  Allen Lazard      48135       WR  IOWA STATE                 12
# 459  2017  Allen Lazard      48135       WR  IOWA STATE                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 42                  11.2                2            48.9
# 192                 11.3                6            61.5
# 320                 13.9                5            59.0
# 459                 12.0                3            56.3
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 42                    NaN  ...                71.4       92           3
# 192                   NaN  ...                98.6       91           6
# 320                   NaN  ...                96.7      117           7
# 459                  39.5  ...               103.3      126          10
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 42        97.9         505    591                238
# 192       79.6         324    808                253
# 320       68.3         286   1018                285
# 459       85.1         422    941                265
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 42                               5.3                 13.1  1.20
# 192                              4.5                 14.4  2.07
# 320                              4.1                 14.8  2.60
# 459                              3.7                 13.3  1.99
#
# [4 rows x 46 columns]
# Amara Darboh      year        player  player_id position team_name  player_game_count  \
# 71   2014  Amara Darboh      11861       WR  MICHIGAN                 12
# 194  2015  Amara Darboh      11861       WR  MICHIGAN                 13
# 328  2016  Amara Darboh      11861       WR  MICHIGAN                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 71                  13.5                4            55.4
# 194                 10.0               10            66.3
# 328                 14.9                7            56.4
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 71                    NaN  ...                63.2       65           2
# 194                   NaN  ...               105.3       89           5
# 328                   NaN  ...               103.7      101           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 71        86.2         257    473                194
# 194       88.3         354    725                311
# 328       90.9         330    862                312
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 71                               5.4                 13.1  1.63
# 194                              5.3                 12.3  1.90
# 328                              5.5                 15.1  2.45
#
# [3 rows x 46 columns]
# Amari Cooper    year        player  player_id position team_name  player_game_count  \
# 0  2014  Amari Cooper       9437       WR   ALABAMA                 14
#
#    avg_depth_of_target  avoided_tackles  caught_percent  contested_catch_rate  \
# 0                  9.9               26            71.3                   NaN
#
#    ...  targeted_qb_rating  targets  touchdowns  wide_rate  wide_snaps  yards  \
# 0  ...               128.7      174          16       79.6         355   1727
#
#    yards_after_catch  yards_after_catch_per_reception  yards_per_reception  \
# 0                878                              7.1                 13.9
#
#    yprr
# 0  3.99
#
# [1 rows x 46 columns]
# Amari Rodgers      year         player  player_id position team_name  player_game_count  \
# 578  2017  Amari Rodgers      61212       WR   CLEMSON                 14
# 674  2018  Amari Rodgers      61212       WR   CLEMSON                 15
# 858  2019  Amari Rodgers      61212       WR   CLEMSON                 13
# 897  2020  Amari Rodgers      61212       WR   CLEMSON                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 578                  2.4                2            86.4
# 674                  6.1               11            77.5
# 858                  6.3                9            75.0
# 897                  7.6               17            77.8
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 578                 100.0  ...                90.0       22           0
# 674                  37.5  ...               113.3       71           4
# 858                  50.0  ...               131.8       40           4
# 897                  14.3  ...               124.7       99           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 578       85.2          98    123                 79
# 674       84.4         265    575                405
# 858        8.2          24    425                335
# 897       13.2          54   1020                613
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 578                              4.2                  6.5  1.09
# 674                              7.4                 10.5  1.89
# 858                             11.2                 14.2  1.60
# 897                              8.0                 13.2  2.61
#
# [4 rows x 46 columns]
# Amon-Ra St. Brown      year             player  player_id position team_name  player_game_count  \
# 655  2018  Amon-Ra St. Brown      84470       WR       USC                 12
# 789  2019  Amon-Ra St. Brown      84470       WR       USC                 13
# 932  2020  Amon-Ra St. Brown      84470       WR       USC                  6
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 655                 12.0                8            69.8
# 789                  9.1               18            74.8
# 932                 10.9                3            71.9
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 655                  33.3  ...                84.0       86           3
# 789                  46.2  ...               117.9      103           6
# 932                  57.1  ...               121.9       57           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 655       35.5         106    750                225
# 789       10.1          57   1042                414
# 932       64.5         176    478                163
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 655                              3.8                 12.5  2.65
# 789                              5.4                 13.5  1.94
# 932                              4.0                 11.7  1.85
#
# [3 rows x 46 columns]
# Andre Baccellia      year           player  player_id position   team_name  player_game_count  \
# 428  2016  Andre Baccellia      47901       WR  WASHINGTON                 14
# 576  2017  Andre Baccellia      47901       WR  WASHINGTON                  8
# 679  2018  Andre Baccellia      47901       WR  WASHINGTON                 14
# 841  2019  Andre Baccellia      47901       WR  WASHINGTON                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 428                 14.3                0            63.6
# 576                 10.4                0            66.7
# 679                  6.8                4            80.6
# 841                  9.8                6            53.7
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 428                   NaN  ...               122.5       11           1
# 576                  50.0  ...                90.1       24           0
# 679                 100.0  ...                84.3       67           0
# 841                  25.0  ...                95.8       54           4
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 428       76.3          74     98                 18
# 576       80.6         108    187                 50
# 679       54.4         186    584                306
# 841       73.8         208    314                155
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 428                              2.6                 14.0  1.03
# 576                              3.1                 11.7  1.48
# 679                              5.7                 10.8  1.81
# 841                              5.3                 10.8  1.17
#
# [4 rows x 46 columns]
# Andre Patton      year        player  player_id position team_name  player_game_count  \
# 103  2014  Andre Patton      12043       WR   RUTGERS                  9
# 234  2015  Andre Patton      12043       WR   RUTGERS                 12
# 379  2016  Andre Patton      12043       WR   RUTGERS                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 103                 10.8                2            47.6
# 234                 11.3                0            59.6
# 379                 16.2                2            54.1
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 103                   NaN  ...                78.1       42           3
# 234                   NaN  ...                67.3       57           1
# 379                   NaN  ...                98.6       61           5
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 103       96.2         150    226                 88
# 234       87.9         311    432                113
# 379       89.4         312    453                 91
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 103                              4.4                 11.3  1.48
# 234                              3.3                 12.7  1.28
# 379                              2.8                 13.7  1.34
#
# [3 rows x 46 columns]
# Andrew Turzilli      year           player  player_id position team_name  player_game_count  \
# 123  2014  Andrew Turzilli      10112       WR   RUTGERS                 11
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 123                 19.8                1            50.0
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 123                   NaN  ...               135.4       20           4
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 123       86.2         119    347                150
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 123                             15.0                 34.7  2.59
#
# [1 rows x 46 columns]
# Andy Isabella      year         player  player_id position team_name  player_game_count  \
# 333  2016  Andy Isabella      47448       WR     UMASS                 12
# 470  2017  Andy Isabella      47448       WR     UMASS                 12
# 608  2018  Andy Isabella      47448       WR     UMASS                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 333                 12.1               13            62.0
# 470                 12.6                9            61.9
# 608                 12.1               18            69.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 333                   NaN  ...                93.8      100           7
# 470                  31.3  ...               121.8      105          10
# 608                  36.0  ...               129.3      146          13
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 333       34.5         152    801                277
# 470       64.3         331   1016                474
# 608       55.8         242   1696                737
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 333                              4.5                 12.9  1.90
# 470                              7.3                 15.6  2.08
# 608                              7.3                 16.8  4.15
#
# [3 rows x 46 columns]
# Anthony Miller      year          player  player_id position team_name  player_game_count  \
# 223  2015  Anthony Miller      48160       WR   MEMPHIS                 12
# 308  2016  Anthony Miller      48160       WR   MEMPHIS                 13
# 452  2017  Anthony Miller      48160       WR   MEMPHIS                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 223                  8.6               18            70.1
# 308                 12.1                7            70.4
# 452                 11.7               19            64.0
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 223                   NaN  ...               128.9       67           5
# 308                   NaN  ...               136.5      135          14
# 452                  41.7  ...               130.0      150          18
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 223       78.8         189    700                401
# 308       69.3         323   1435                541
# 452       61.2         274   1459                713
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 223                              8.5                 14.9  2.98
# 308                              5.7                 15.1  3.22
# 452                              7.4                 15.2  3.47
#
# [3 rows x 46 columns]
# Anthony Schwartz      year            player  player_id position team_name  player_game_count  \
# 718  2018  Anthony Schwartz      84135       WR    AUBURN                 13
# 844  2019  Anthony Schwartz      84135       WR    AUBURN                 12
# 903  2020  Anthony Schwartz      84135       WR    AUBURN                 10
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 718                  7.8                5            61.1
# 844                  8.6                1            77.4
# 903                  8.0                4            63.5
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 718                   0.0  ...               101.0       36           2
# 844                  80.0  ...               107.3       53           1
# 903                  33.3  ...                83.2       85           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 718       63.6         124    355                268
# 844       57.8          96    438                255
# 903       47.8         138    635                488
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 718                             12.2                 16.1  1.91
# 844                              6.2                 10.7  2.75
# 903                              9.0                 11.8  2.31
#
# [3 rows x 46 columns]
# Antoine Green       year         player  player_id position   team_name  player_game_count  \
# 753   2018  Antoine Green      77985       WR  N CAROLINA                  5
# 871   2019  Antoine Green      77985       WR  N CAROLINA                 10
# 982   2020  Antoine Green      77985       WR  N CAROLINA                 11
# 1039  2021  Antoine Green      77985       WR  N CAROLINA                 13
# 1080  2022  Antoine Green      77985       WR  N CAROLINA                  9
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 753                  19.4                0            57.1
# 871                  17.8                2            42.1
# 982                  12.0                1            57.1
# 1039                 19.0                2            66.0
# 1080                 18.1               12            66.2
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 753                  100.0  ...                76.5        7           0
# 871                    0.0  ...               119.8       19           2
# 982                    NaN  ...                72.3        7           1
# 1039                  77.8  ...               144.6       47           5
# 1080                  50.0  ...               144.3       65           7
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 753        96.4          27     45                  3
# 871        97.9         143    217                 70
# 982        98.5          64     38                 19
# 1039       95.8         429    612                160
# 1080       97.7         344    798                221
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 753                               0.8                 11.3  1.67
# 871                               8.8                 27.1  1.58
# 982                               4.8                  9.5  0.63
# 1039                              5.2                 19.7  1.44
# 1080                              5.1                 18.6  2.34
#
# [5 rows x 46 columns]
# Antoine Wesley      year          player  player_id position   team_name  player_game_count  \
# 447  2016  Antoine Wesley      39967       WR  TEXAS TECH                  4
# 588  2017  Antoine Wesley      39967       WR  TEXAS TECH                 11
# 613  2018  Antoine Wesley      39967       WR  TEXAS TECH                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 447                 34.5                0             0.0
# 588                 11.3                0            83.3
# 613                 12.1               12            69.3
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 447                   NaN  ...                39.6        2           0
# 588                  75.0  ...                79.5       12           0
# 613                  53.6  ...               126.4      127           9
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 447       96.4          27      0                  0
# 588        5.5           3    137                 29
# 613       93.8         540   1408                628
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 447                              NaN                  NaN  0.00
# 588                              2.9                 13.7  2.63
# 613                              7.1                 16.0  2.59
#
# [3 rows x 46 columns]
# Antonio Callaway      year            player  player_id position team_name  player_game_count  \
# 217  2015  Antonio Callaway      48101       WR   FLORIDA                 14
# 350  2016  Antonio Callaway      48101       WR   FLORIDA                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 217                 14.6                4            49.3
# 350                 11.1                8            63.5
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 217                   NaN  ...               101.8       71           4
# 350                   NaN  ...                77.6       85           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 217       69.7         287    680                279
# 350       91.3         313    721                373
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 217                              8.0                 19.4  1.71
# 350                              6.9                 13.4  2.17
#
# [2 rows x 46 columns]
# Antonio Gandy-Golden      year                player  player_id position team_name  \
# 617  2018  Antonio Gandy-Golden      39993       WR   LIBERTY
# 763  2019  Antonio Gandy-Golden      39993       WR   LIBERTY
#
#      player_game_count  avg_depth_of_target  avoided_tackles  caught_percent  \
# 617                 11                 14.3               17            56.0
# 763                 13                 15.0               16            57.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 617                  52.9  ...                92.9      125          10
# 763                  45.9  ...               104.0      138          10
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 617       92.8         415   1024                345
# 763       89.2         445   1397                472
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 617                              4.9                 14.6  2.40
# 763                              6.0                 17.7  2.95
#
# [2 rows x 46 columns]
# ArDarius Stewart      year            player  player_id position team_name  player_game_count  \
# 124  2014  ArDarius Stewart      11834       WR   ALABAMA                  8
# 184  2015  ArDarius Stewart      11834       WR   ALABAMA                 15
# 356  2016  ArDarius Stewart      11834       WR   ALABAMA                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 124                 13.9                1            66.7
# 184                  9.9               23            63.4
# 356                  9.3               18            70.1
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 124                   NaN  ...                69.0       18           0
# 184                   NaN  ...                84.5      101           4
# 356                   NaN  ...               113.8       77           8
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 124       72.2          39    149                 60
# 184       74.5         359    697                401
# 356       73.7         252    845                569
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 124                              5.0                 12.4  2.87
# 184                              6.3                 10.9  1.52
# 356                             10.5                 15.6  2.60
#
# [3 rows x 46 columns]
# Auden Tate      year      player  player_id position   team_name  player_game_count  \
# 395  2016  Auden Tate      48192       WR  FLORIDA ST                 13
# 516  2017  Auden Tate      48192       WR  FLORIDA ST                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 395                 15.7                2            55.6
# 516                 13.4                4            59.7
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 395                   NaN  ...               116.4       45           6
# 516                  66.7  ...                94.4       67          10
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 395       85.7         239    407                109
# 516       88.2         283    548                124
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 395                              4.4                 16.3  1.55
# 516                              3.1                 13.7  1.79
#
# [2 rows x 46 columns]
# Austin Carr      year       player  player_id position team_name  player_game_count  \
# 126  2014  Austin Carr      12215       WR  NWESTERN                 12
# 262  2015  Austin Carr      12215       WR  NWESTERN                 12
# 310  2016  Austin Carr      12215       WR  NWESTERN                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 126                 10.4                1            43.8
# 262                 11.8                1            61.5
# 310                 10.7                9            69.8
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 126                   NaN  ...                64.6       16           0
# 262                   NaN  ...                95.4       26           2
# 310                   NaN  ...               118.6      129          12
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 126       16.2          17    100                 72
# 262       39.1          72    302                112
# 310        2.2          10   1247                435
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 126                             10.3                 14.3  1.02
# 262                              7.0                 18.9  1.67
# 310                              4.8                 13.9  2.85
#
# [3 rows x 46 columns]
# Austin Mack      year       player  player_id position   team_name  player_game_count  \
# 441  2016  Austin Mack      28070       WR  OHIO STATE                  6
# 554  2017  Austin Mack      28070       WR  OHIO STATE                 14
# 714  2018  Austin Mack      28070       WR  OHIO STATE                  8
# 859  2019  Austin Mack      28070       WR  OHIO STATE                 11
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 441                  7.6                0            40.0
# 554                 11.9                1            63.2
# 714                 12.0                3            61.9
# 859                 13.6                4            69.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 441                   NaN  ...                47.9        5           0
# 554                  75.0  ...                98.9       38           2
# 714                  54.5  ...                94.4       42           1
# 859                  57.1  ...               124.0       39           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 441       91.5          43     15                 -1
# 554       90.0         226    343                 72
# 714       89.5         179    331                 68
# 859       86.4         165    361                 69
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 441                             -0.5                  7.5  0.33
# 554                              3.0                 14.3  1.46
# 714                              2.6                 12.7  1.76
# 859                              2.6                 13.4  2.02
#
# [4 rows x 46 columns]
# Austin Trammell      year           player  player_id position team_name  player_game_count  \
# 591  2017  Austin Trammell      52195       WR      RICE                 12
# 632  2018  Austin Trammell      52195       WR      RICE                 13
# 783  2019  Austin Trammell      52195       WR      RICE                 12
# 973  2020  Austin Trammell      52195       WR      RICE                  3
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 591                 18.2                0            36.4
# 632                  7.4                6            58.5
# 783                 10.3                9            57.1
# 973                 14.3                3            84.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 591                   0.0  ...                12.1       11           0
# 632                  38.5  ...                57.6      106           3
# 783                  40.0  ...                87.2      105           4
# 973                 100.0  ...               158.3       19           6
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 591       59.5          47     51                  7
# 632       26.2         108    632                271
# 783       22.5          82    726                274
# 973       48.4          44    335                136
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 591                              1.8                 12.8  0.66
# 632                              4.4                 10.2  1.57
# 783                              4.6                 12.1  2.10
# 973                              8.5                 20.9  3.85
#
# [4 rows x 46 columns]
# Ben Skowronek      year         player  player_id position   team_name  player_game_count  \
# 410  2016  Ben Skowronek      27948       WR    NWESTERN                 13
# 497  2017  Ben Skowronek      27948       WR    NWESTERN                 13
# 668  2018  Ben Skowronek      27948       WR    NWESTERN                 14
# 872  2019  Ben Skowronek      27948       WR    NWESTERN                  3
# 947  2020  Ben Skowronek      27948       WR  NOTRE DAME                 10
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 410                 10.8                0            30.8
# 497                 13.5                4            60.0
# 668                 12.4                1            60.8
# 872                  8.2                2            66.7
# 947                 11.9                5            65.9
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 410                   NaN  ...                40.2       26           0
# 497                  50.0  ...                99.0       75           5
# 668                  57.1  ...                69.8       74           3
# 872                  66.7  ...                50.7       18           0
# 947                  66.7  ...               136.4       44           5
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 410       93.9         168     70                  8
# 497       90.7         390    645                121
# 668       92.1         433    562                136
# 872       70.3          64    141                 36
# 947       92.1         293    438                181
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 410                              1.0                  8.8  0.41
# 497                              2.7                 14.3  1.57
# 668                              3.0                 12.5  1.25
# 872                              3.0                 11.8  1.68
# 947                              6.2                 15.1  1.46
#
# [5 rows x 46 columns]
# Bo Melton       year     player  player_id position team_name  player_game_count  \
# 590   2017  Bo Melton      61610       WR   RUTGERS                 11
# 695   2018  Bo Melton      61610       WR   RUTGERS                 12
# 848   2019  Bo Melton      61610       WR   RUTGERS                 12
# 914   2020  Bo Melton      61610       WR   RUTGERS                  9
# 1010  2021  Bo Melton      61610       WR   RUTGERS                 11
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 590                  12.8                0            33.3
# 695                  10.6                3            47.4
# 848                  12.9                7            62.5
# 914                  11.9               11            63.5
# 1010                 10.8               12            61.5
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 590                    0.0  ...                58.7       12           0
# 695                   23.1  ...                37.5       57           0
# 848                   62.5  ...                79.1       48           2
# 914                   31.3  ...               101.2       74           6
# 1010                  25.0  ...                89.2       91           3
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 590        78.2          97     83                 13
# 695        82.5         245    245                104
# 848        83.5         227    427                167
# 914        81.5         269    640                271
# 1010       78.2         229    642                354
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 590                               3.3                 20.8  0.72
# 695                               3.9                  9.1  0.87
# 848                               5.6                 14.2  1.66
# 914                               5.8                 13.6  2.08
# 1010                              6.3                 11.5  2.28
#
# [5 rows x 46 columns]
# Bobo Wilson      year       player  player_id position   team_name  player_game_count  \
# 67   2014  Bobo Wilson      12067       WR  FLORIDA ST                 13
# 196  2015  Bobo Wilson      12067       WR  FLORIDA ST                 13
# 389  2016  Bobo Wilson      12067       WR  FLORIDA ST                  7
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 67                  11.9                0            62.7
# 196                 11.4                2            66.7
# 389                  9.6                3            61.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 67                    NaN  ...                94.6       67           4
# 196                   NaN  ...                84.9       87           3
# 389                   NaN  ...                93.1       49           1
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 67        68.3         272    527                145
# 196       91.6         382    630                144
# 389       91.3         190    390                107
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 67                               3.5                 12.5  1.38
# 196                              2.5                 10.9  1.57
# 389                              3.6                 13.0  1.97
#
# [3 rows x 46 columns]
# Bradley Marquez     year           player  player_id position   team_name  player_game_count  \
# 24  2014  Bradley Marquez       9914       WR  TEXAS TECH                 12
#
#     avg_depth_of_target  avoided_tackles  caught_percent  \
# 24                 11.3               11            61.3
#
#     contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 24                   NaN  ...                97.2      106          10
#
#     wide_rate  wide_snaps  yards  yards_after_catch  \
# 24       46.7         227    819                306
#
#     yards_after_catch_per_reception  yards_per_reception  yprr
# 24                              4.7                 12.6   1.8
#
# [1 rows x 46 columns]
# Bralon Addison      year          player  player_id position team_name  player_game_count  \
# 191  2015  Bralon Addison      11013       WR    OREGON                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 191                 10.7               13            69.2
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 191                   NaN  ...               128.6       91          10
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 191       31.2         120    804                342
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 191                              5.4                 12.8  2.18
#
# [1 rows x 46 columns]
# Brandon Aiyuk      year         player  player_id position   team_name  player_game_count  \
# 706  2018  Brandon Aiyuk      84109       WR  ARIZONA ST                 13
# 793  2019  Brandon Aiyuk      84109       WR  ARIZONA ST                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 706                 11.6                9            70.2
# 793                 10.1               14            65.7
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 706                  16.7  ...               106.2       47           3
# 793                  25.0  ...               133.9       99           8
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 706       91.7         209    474                256
# 793       82.7         340   1192                710
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 706                              7.8                 14.4  2.16
# 793                             10.9                 18.3  3.04
#
# [2 rows x 46 columns]
# Brandon Johnson       year           player  player_id position  team_name  player_game_count  \
# 432   2016  Brandon Johnson      40666       WR  TENNESSEE                  8
# 532   2017  Brandon Johnson      40666       WR  TENNESSEE                 12
# 734   2018  Brandon Johnson      40666       WR  TENNESSEE                  9
# 888   2019  Brandon Johnson      40666       WR  TENNESSEE                  4
# 960   2020  Brandon Johnson      40666       WR  TENNESSEE                  9
# 1028  2021  Brandon Johnson      40666       WR        UCF                 13
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 432                   8.1                1            77.8
# 532                  10.5                3            67.3
# 734                   7.5                3            63.6
# 888                  10.6                2            40.0
# 960                  10.1                3            63.3
# 1028                 14.2                4            56.7
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 432                    NaN  ...               109.7        9           0
# 532                   22.2  ...                78.0       55           1
# 734                   40.0  ...                61.2       22           0
# 888                    NaN  ...                61.3        5           0
# 960                   42.9  ...                86.9       30           0
# 1028                  61.5  ...               111.3       67          11
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 432        97.6          40     93                 49
# 532        22.3          59    482                155
# 734         6.7           9    132                 70
# 888        63.6          14     31                 18
# 960        15.1          26    231                 72
# 1028       82.6         352    560                154
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 432                               7.0                 13.3  2.38
# 532                               4.2                 13.0  1.91
# 734                               5.0                  9.4  1.09
# 888                               9.0                 15.5  1.41
# 960                               3.8                 12.2  1.42
# 1028                              4.1                 14.7  1.37
#
# [6 rows x 46 columns]
# Brandon Powell      year          player  player_id position team_name  player_game_count  \
# 248  2015  Brandon Powell      48036       WR   FLORIDA                 14
# 369  2016  Brandon Powell      48036       WR   FLORIDA                 13
# 510  2017  Brandon Powell      48036       WR   FLORIDA                 11
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 248                  6.2                8            64.4
# 369                  7.1                4            67.2
# 510                  8.0                4            61.8
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 248                   NaN  ...               114.1       45           3
# 369                   NaN  ...                73.4       67           2
# 510                   0.0  ...                87.0       68           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 248       14.4          49    390                215
# 369       20.8          69    387                249
# 510        9.0          23    406                196
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 248                              7.4                 13.4  1.17
# 369                              5.5                  8.6  1.22
# 510                              4.7                  9.7  1.63
#
# [3 rows x 46 columns]
# Braxton Berrios      year           player  player_id position team_name  player_game_count  \
# 106  2014  Braxton Berrios      47961       WR  MIAMI FL                 13
# 279  2015  Braxton Berrios      47961       WR  MIAMI FL                 11
# 417  2016  Braxton Berrios      47961       WR  MIAMI FL                 13
# 486  2017  Braxton Berrios      47961       WR  MIAMI FL                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 106                 11.7                2            51.2
# 279                  4.5                1            85.7
# 417                 16.0                0            57.1
# 486                 10.9                8            65.5
#
# ...
# 568                  33.3  ...               139.9       27           3
# 643                  52.0  ...               105.8       91           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 273       93.8         120    150                 56
# 568       61.0          75    293                105
# 643       94.0         499    845                227
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 273                              6.2                 16.7  1.20
# 568                              5.8                 16.3  2.57
# 643                              4.3                 15.9  1.68
#
# [3 rows x 46 columns]
# Van Jefferson      year         player  player_id position team_name  player_game_count  \
# 365  2016  Van Jefferson      47447       WR  OLE MISS                 12
# 534  2017  Van Jefferson      47447       WR  OLE MISS                 10
# 680  2018  Van Jefferson      47447       WR   FLORIDA                 13
# 822  2019  Van Jefferson      47447       WR   FLORIDA                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 365                 12.1                6            68.1
# 534                  7.8                4            75.9
# 680                 16.3                4            53.0
# 822                 10.3                3            71.0
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 365                   NaN  ...                98.3       72           3
# 534                  37.5  ...               106.5       54           1
# 680                  30.8  ...               102.0       66           6
# 822                  50.0  ...               117.8       69           6
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 365        2.7          12    543                185
# 534       34.9          98    453                167
# 680       79.8         257    503                165
# 822       69.9         253    657                266
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 365                              3.8                 11.1  1.29
# 534                              4.1                 11.0  1.68
# 680                              4.7                 14.4  1.67
# 822                              5.4                 13.4  2.00
#
# [4 rows x 46 columns]
# Velus Jones Jr.       year           player  player_id position  team_name  player_game_count  \
# 724   2018  Velus Jones Jr.      40573       WR        USC                 12
# 887   2019  Velus Jones Jr.      40573       WR        USC                  8
# 958   2020  Velus Jones Jr.      40573       WR  TENNESSEE                 10
# 1018  2021  Velus Jones Jr.      40573       WR  TENNESSEE                 13
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 724                   8.7                3            70.6
# 887                   2.3                1           100.0
# 958                   9.3                5            71.0
# 1018                  7.1               16            76.5
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 724                   20.0  ...                91.1       34           1
# 887                  100.0  ...                91.0        6           0
# 958                   50.0  ...               131.1       31           3
# 1018                  50.0  ...               131.0       81           7
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 724        10.8          18    266                155
# 887        86.0          43     35                 21
# 958        77.7         139    280                176
# 1018       17.0          54    807                516
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 724                               6.5                 11.1  1.67
# 887                               3.5                  5.8  0.74
# 958                               8.0                 12.7  1.67
# 1018                              8.3                 13.0  2.67
#
# [4 rows x 46 columns]
# Ventell Bryant      year          player  player_id position team_name  player_game_count  \
# 219  2015  Ventell Bryant      47959       WR    TEMPLE                 14
# 343  2016  Ventell Bryant      47959       WR    TEMPLE                 11
# 527  2017  Ventell Bryant      47959       WR    TEMPLE                 10
# 653  2018  Ventell Bryant      47959       WR    TEMPLE                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 219                 11.5                9            55.7
# 343                 14.5               10            59.3
# 527                 13.7                2            48.3
# 653                 14.6                9            59.3
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 219                   NaN  ...                91.3       70           3
# 343                   NaN  ...                98.0       91           4
# 527                  30.0  ...                47.5       58           0
# 653                  36.0  ...                77.2       86           3
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 219       95.9         260    579                277
# 343       97.3         251    895                225
# 527       93.6         221    272                 76
# 653       87.7         284    690                171
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 219                              7.1                 14.8  2.34
# 343                              4.2                 16.6  3.62
# 527                              2.7                  9.7  1.20
# 653                              3.4                 13.5  2.18
#
# [4 rows x 46 columns]
# Victor Bolden Jr.      year             player  player_id position  team_name  \
# 21   2014  Victor Bolden Jr.      12269       WR  OREGON ST
# 197  2015  Victor Bolden Jr.      12269       WR  OREGON ST
# 346  2016  Victor Bolden Jr.      12269       WR  OREGON ST
#
#      player_game_count  avg_depth_of_target  avoided_tackles  caught_percent  \
# 21                  11                 10.6                7            67.3
# 197                 12                 11.1                6            53.5
# 346                 12                 11.3                9            52.8
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 21                    NaN  ...                95.5      107           2
# 197                   NaN  ...                51.6       86           3
# 346                   NaN  ...                60.4       89           2
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 21        96.2         429    798                254
# 197       16.9          67    461                172
# 346       11.5          45    545                260
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 21                               3.5                 11.1  1.88
# 197                              3.7                 10.0  1.24
# 346                              5.5                 11.6  1.48
#
# [3 rows x 46 columns]
# Vince Mayle    year       player  player_id position   team_name  player_game_count  \
# 2  2014  Vince Mayle       9556       WR  WASH STATE                 12
#
#    avg_depth_of_target  avoided_tackles  caught_percent  contested_catch_rate  \
# 2                  9.8               25            65.0                   NaN
#
#    ...  targeted_qb_rating  targets  touchdowns  wide_rate  wide_snaps  yards  \
# 2  ...               104.9      163           9       99.3         575   1483
#
#    yards_after_catch  yards_after_catch_per_reception  yards_per_reception  \
# 2                827                              7.8                 14.0
#
#    yprr
# 2  2.69
#
# [1 rows x 46 columns]
# Wan'Dale Robinson      year             player  player_id position team_name  player_game_count  \
# 922  2020  Wan'Dale Robinson     101735       WR  NEBRASKA                  8
# 988  2021  Wan'Dale Robinson     101735       WR  KENTUCKY                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 922                  6.2                4            79.7
# 988                 10.4               22            74.3
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 922                  85.7  ...                88.9       64           1
# 988                  52.9  ...               105.7      140           7
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 922       11.6          28    461                262
# 988       27.8         108   1342                599
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 922                              5.1                  9.0  1.99
# 988                              5.8                 12.9  3.56
#
# [2 rows x 46 columns]
# Will Fuller V      year         player  player_id position   team_name  player_game_count  \
# 18   2014  Will Fuller V      10655       WR  NOTRE DAME                 13
# 185  2015  Will Fuller V      10655       WR  NOTRE DAME                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 18                  11.8                5            68.5
# 185                 15.1                5            62.0
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 18                    NaN  ...               136.0      111          15
# 185                   NaN  ...               124.6      100          14
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 18        94.2         502   1094                420
# 185       93.2         427   1259                414
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 18                               5.5                 14.4  2.15
# 185                              6.7                 20.3  2.91
#
# [2 rows x 46 columns]
# Xavier Hutchinson       year             player  player_id position   team_name  \
# 898   2020  Xavier Hutchinson     122518       WR  IOWA STATE
# 1003  2021  Xavier Hutchinson     122518       WR  IOWA STATE
# 1053  2022  Xavier Hutchinson     122518       WR  IOWA STATE
#
#       player_game_count  avg_depth_of_target  avoided_tackles  caught_percent  \
# 898                  12                 10.2               16            68.8
# 1003                 13                  7.8               11            79.8
# 1053                 12                  9.2               15            66.5
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 898                   47.6  ...                94.9       93           4
# 1003                  58.3  ...               110.3      104           5
# 1053                  45.2  ...                92.4      161           6
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 898        80.9         305    771                374
# 1003       77.2         318    990                510
# 1053       70.1         316   1171                447
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 898                               5.8                 12.0  2.18
# 1003                              6.1                 11.9  2.55
# 1053                              4.2                 10.9  2.72
#
# [3 rows x 46 columns]
# Zach Pascal      year       player  player_id position team_name  player_game_count  \
# 29   2014  Zach Pascal      12303       WR  DOMINION                 12
# 171  2015  Zach Pascal      12303       WR  DOMINION                 12
# 330  2016  Zach Pascal      12303       WR  DOMINION                 13
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 29                  13.3                5            59.0
# 171                 13.3               13            57.5
# 330                 13.8                6            64.4
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 29                    NaN  ...                84.7      100           7
# 171                   NaN  ...                88.7      120           8
# 330                   NaN  ...               120.3      101           9
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 29        84.0         431    742                178
# 171       65.4         298    975                368
# 330       47.8         178    946                270
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 29                               3.0                 12.6  1.54
# 171                              5.3                 14.1  2.23
# 330                              4.2                 14.6  2.70
#
# [3 rows x 46 columns]
# Zay Flowers       year       player  player_id position   team_name  player_game_count  \
# 860   2019  Zay Flowers      97268       WR  BOSTON COL                 13
# 894   2020  Zay Flowers      97268       WR  BOSTON COL                 11
# 1017  2021  Zay Flowers      97268       WR  BOSTON COL                 12
# 1058  2022  Zay Flowers      97268       WR  BOSTON COL                 12
#
#       avg_depth_of_target  avoided_tackles  caught_percent  \
# 860                  13.1                6            57.9
# 894                  14.4                9            53.4
# 1017                 15.2               10            53.7
# 1058                 10.4               15            62.9
#
#       contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 860                   33.3  ...               114.0       38           3
# 894                   33.3  ...                99.7      103           9
# 1017                  35.7  ...                84.7       82           5
# 1058                  58.3  ...               106.1      124          12
#
#       wide_rate  wide_snaps  yards  yards_after_catch  \
# 860        81.3         156    341                147
# 894        51.6         227    892                368
# 1017       74.1         255    746                326
# 1058       66.6         337   1077                503
#
#       yards_after_catch_per_reception  yards_per_reception  yprr
# 860                               6.7                 15.5  1.82
# 894                               6.7                 16.2  2.15
# 1017                              7.4                 17.0  2.27
# 1058                              6.4                 13.8  2.22
#
# [4 rows x 46 columns]
# Zay Jones      year     player  player_id position   team_name  player_game_count  \
# 16   2014  Zay Jones      11792       WR  E CAROLINA                 13
# 166  2015  Zay Jones      11792       WR  E CAROLINA                 12
# 299  2016  Zay Jones      11792       WR  E CAROLINA                 12
#
#      avg_depth_of_target  avoided_tackles  caught_percent  \
# 16                   7.2               11            71.7
# 166                  7.6               23            78.4
# 299                  8.5               24            73.1
#
#      contested_catch_rate  ...  targeted_qb_rating  targets  touchdowns  \
# 16                    NaN  ...               103.1      113           5
# 166                   NaN  ...               113.1      125           5
# 299                   NaN  ...                99.4      216           8
#
#      wide_rate  wide_snaps  yards  yards_after_catch  \
# 16        14.5          87    820                350
# 166        4.5          22   1094                541
# 299       68.7         424   1744                790
#
#      yards_after_catch_per_reception  yards_per_reception  yprr
# 16                               4.3                 10.1  1.45
# 166                              5.5                 11.2  2.32
# 299                              5.0                 11.0  2.96
#
# [3 rows x 46 columns]

# %%
for index, row in ncaa.head(10).iterrows():
    print(row)
# Out:
# year                                       2014
# player                             Amari Cooper
# player_id                                  9437
# position                                     WR
# team_name                               ALABAMA
# player_game_count                            14
# avg_depth_of_target                         9.9
# avoided_tackles                              26
# caught_percent                             71.3
# contested_catch_rate                        NaN
# contested_receptions                          0
# contested_targets                             0
# declined_penalties                            0
# drop_rate                                   6.1
# drops                                         8
# first_downs                                   0
# franchise_id                                103
# fumbles                                       0
# grades_hands_drop                          79.4
# grades_hands_fumble                        78.8
# grades_offense                             92.8
# grades_pass_block                           NaN
# grades_pass_route                          93.3
# inline_rate                                 0.0
# inline_snaps                                  0
# interceptions                                 2
# longest                                      80
# pass_block_rate                             0.0
# pass_blocks                                   0
# pass_plays                                  446
# penalties                                     2
# receptions                                  124
# route_rate                                 97.1
# routes                                      433
# slot_rate                                  19.5
# slot_snaps                                   87
# targeted_qb_rating                        128.7
# targets                                     174
# touchdowns                                   16
# wide_rate                                  79.6
# wide_snaps                                  355
# yards                                      1727
# yards_after_catch                           878
# yards_after_catch_per_reception             7.1
# yards_per_reception                        13.9
# yprr                                       3.99
# Name: 0, dtype: object
# year                                       2014
# player                             Justin Hardy
# player_id                                  9540
# position                                     WR
# team_name                            E CAROLINA
# player_game_count                            13
# avg_depth_of_target                         9.5
# avoided_tackles                              20
# caught_percent                             72.5
# contested_catch_rate                        NaN
# contested_receptions                          0
# contested_targets                             0
# declined_penalties                            0
# drop_rate                                   4.0
# drops                                         5
# first_downs                                   0
# franchise_id                                156
# fumbles                                       1
# grades_hands_drop                          85.0
# grades_hands_fumble                        78.2
# grades_offense                             89.5
# grades_pass_block                          68.5
# grades_pass_route                          89.2
# inline_rate                                 0.0
# inline_snaps                                  0
# interceptions                                 5
# longest                                      66
# pass_block_rate                             0.2
# pass_blocks                                   1
# pass_plays                                  659
# penalties                                     3
# receptions                                  121
# route_rate                                 94.8
# routes                                      625
# slot_rate                                  64.2
# slot_snaps                                  423
# targeted_qb_rating                        107.2
# targets                                     167
# touchdowns                                   10
# wide_rate                                  35.1
# wide_snaps                                  231
# yards                                      1494
# yards_after_catch                           612
# yards_after_catch_per_reception             5.1
# yards_per_reception                        12.3
# yprr                                       2.39
# Name: 1, dtype: object
# year                                      2014
# player                             Vince Mayle
# player_id                                 9556
# position                                    WR
# team_name                           WASH STATE
# player_game_count                           12
# avg_depth_of_target                        9.8
# avoided_tackles                             25
# caught_percent                            65.0
# contested_catch_rate                       NaN
# contested_receptions                         0
# contested_targets                            0
# declined_penalties                           0
# drop_rate                                 15.2
# drops                                       19
# first_downs                                  0
# franchise_id                               341
# fumbles                                      1
# grades_hands_drop                         43.9
# grades_hands_fumble                       60.8
# grades_offense                            76.7
# grades_pass_block                          NaN
# grades_pass_route                         75.3
# inline_rate                                0.0
# inline_snaps                                 0
# interceptions                                3
# longest                                     90
# pass_block_rate                            0.0
# pass_blocks                                  0
# pass_plays                                 579
# penalties                                    3
# receptions                                 106
# route_rate                                95.2
# routes                                     551
# slot_rate                                  0.7
# slot_snaps                                   4
# targeted_qb_rating                       104.9
# targets                                    163
# touchdowns                                   9
# wide_rate                                 99.3
# wide_snaps                                 575
# yards                                     1483
# yards_after_catch                          827
# yards_after_catch_per_reception            7.8
# yards_per_reception                       14.0
# yprr                                      2.69
# Name: 2, dtype: object
# year                                      2014
# player                             Kevin White
# player_id                                 9440
# position                                    WR
# team_name                           W VIRGINIA
# player_game_count                           13
# avg_depth_of_target                       11.1
# avoided_tackles                             24
# caught_percent                            68.1
# contested_catch_rate                       NaN
# contested_receptions                         0
# contested_targets                            0
# declined_penalties                           0
# drop_rate                                  7.6
# drops                                        9
# first_downs                                  0
# franchise_id                               343
# fumbles                                      1
# grades_hands_drop                         72.6
# grades_hands_fumble                       61.2
# grades_offense                            78.5
# grades_pass_block                          NaN
# grades_pass_route                         78.2
# inline_rate                                0.5
# inline_snaps                                 3
# interceptions                                5
# longest                                     68
# pass_block_rate                            0.0
# pass_blocks                                  0
# pass_plays                                 590
# penalties                                    5
# receptions                                 109
# route_rate                                94.6
# routes                                     558
# slot_rate                                  7.6
# slot_snaps                                  45
# targeted_qb_rating                       104.3
# targets                                    160
# touchdowns                                  10
# wide_rate                                 90.7
# wide_snaps                                 535
# yards                                     1447
# yards_after_catch                          679
# yards_after_catch_per_reception            6.2
# yards_per_reception                       13.3
# yprr                                      2.59
# Name: 3, dtype: object
# year                                        2014
# player                             Jaelen Strong
# player_id                                   9503
# position                                      WR
# team_name                             ARIZONA ST
# player_game_count                             12
# avg_depth_of_target                         13.9
# avoided_tackles                                7
# caught_percent                              53.3
# contested_catch_rate                         NaN
# contested_receptions                           0
# contested_targets                              0
# declined_penalties                             1
# drop_rate                                    8.0
# drops                                          7
# first_downs                                    1
# franchise_id                                 110
# fumbles                                        0
# grades_hands_drop                           70.3
# grades_hands_fumble                         76.2
# grades_offense                              86.6
# grades_pass_block                            NaN
# grades_pass_route                           87.5
# inline_rate                                  0.0
# inline_snaps                                   0
# interceptions                                  3
# longest                                       77
# pass_block_rate                              0.0
# pass_blocks                                    0
# pass_plays                                   455
# penalties                                      2
# receptions                                    81
# route_rate                                  94.7
# routes                                       431
# slot_rate                                   25.3
# slot_snaps                                   115
# targeted_qb_rating                          92.2
# targets                                      152
# touchdowns                                    10
# wide_rate                                   74.7
# wide_snaps                                   340
# yards                                       1168
# yards_after_catch                            421
# yards_after_catch_per_reception              5.2
# yards_per_reception                         14.4
# yprr                                        2.71
# Name: 4, dtype: object
# year                                          2014
# player                             Jamison Crowder
# player_id                                     9538
# position                                        WR
# team_name                                     DUKE
# player_game_count                               13
# avg_depth_of_target                           11.0
# avoided_tackles                                 11
# caught_percent                                56.4
# contested_catch_rate                           NaN
# contested_receptions                             0
# contested_targets                                0
# declined_penalties                               0
# drop_rate                                     10.6
# drops                                           10
# first_downs                                      1
# franchise_id                                   154
# fumbles                                          1
# grades_hands_drop                             60.8
# grades_hands_fumble                           58.1
# grades_offense                                73.0
# grades_pass_block                              NaN
# grades_pass_route                             73.1
# inline_rate                                    0.0
# inline_snaps                                     0
# interceptions                                    4
# longest                                         52
# pass_block_rate                                0.0
# pass_blocks                                      0
# pass_plays                                     474
# penalties                                        2
# receptions                                      84
# route_rate                                    97.0
# routes                                         460
# slot_rate                                     17.3
# slot_snaps                                      82
# targeted_qb_rating                            81.1
# targets                                        149
# touchdowns                                       6
# wide_rate                                     81.9
# wide_snaps                                     388
# yards                                         1064
# yards_after_catch                              550
# yards_after_catch_per_reception                6.5
# yards_per_reception                           12.7
# yprr                                          2.31
# Name: 5, dtype: object
# year                                        2014
# player                             Tyler Lockett
# player_id                                   9502
# position                                      WR
# team_name                              KANSAS ST
# player_game_count                             13
# avg_depth_of_target                         11.9
# avoided_tackles                                9
# caught_percent                              72.1
# contested_catch_rate                         NaN
# contested_receptions                           0
# contested_targets                              0
# declined_penalties                             0
# drop_rate                                    6.2
# drops                                          7
# first_downs                                    0
# franchise_id                                 199
# fumbles                                        0
# grades_hands_drop                           79.1
# grades_hands_fumble                         78.0
# grades_offense                              92.7
# grades_pass_block                            NaN
# grades_pass_route                           92.8
# inline_rate                                  0.0
# inline_snaps                                   0
# interceptions                                  3
# longest                                       70
# pass_block_rate                              0.0
# pass_blocks                                    0
# pass_plays                                   445
# penalties                                      3
# receptions                                   106
# route_rate                                  93.3
# routes                                       415
# slot_rate                                   15.3
# slot_snaps                                    68
# targeted_qb_rating                         121.6
# targets                                      147
# touchdowns                                    11
# wide_rate                                   84.3
# wide_snaps                                   375
# yards                                       1515
# yards_after_catch                            455
# yards_after_catch_per_reception              4.3
# yards_per_reception                         14.3
# yprr                                        3.65
# Name: 6, dtype: object
# year                                            2014
# player                             Rashad Greene Sr.
# player_id                                       9572
# position                                          WR
# team_name                                 FLORIDA ST
# player_game_count                                 14
# avg_depth_of_target                             11.0
# avoided_tackles                                   17
# caught_percent                                  69.7
# contested_catch_rate                             NaN
# contested_receptions                               0
# contested_targets                                  0
# declined_penalties                                 0
# drop_rate                                        3.9
# drops                                              4
# first_downs                                        1
# franchise_id                                     167
# fumbles                                            0
# grades_hands_drop                               86.2
# grades_hands_fumble                             77.1
# grades_offense                                  82.2
# grades_pass_block                                NaN
# grades_pass_route                               83.3
# inline_rate                                      0.0
# inline_snaps                                       0
# interceptions                                      4
# longest                                           74
# pass_block_rate                                  0.0
# pass_blocks                                        0
# pass_plays                                       546
# penalties                                          0
# receptions                                        99
# route_rate                                      96.2
# routes                                           525
# slot_rate                                       22.3
# slot_snaps                                       122
# targeted_qb_rating                             104.9
# targets                                          142
# touchdowns                                         7
# wide_rate                                       76.7
# wide_snaps                                       419
# yards                                           1365
# yards_after_catch                                599
# yards_after_catch_per_reception                  6.1
# yards_per_reception                             13.8
# yprr                                             2.6
# Name: 7, dtype: object
# year                                           2014
# player                             DaeSean Hamilton
# player_id                                     45416
# position                                         WR
# team_name                                PENN STATE
# player_game_count                                13
# avg_depth_of_target                             8.8
# avoided_tackles                                  10
# caught_percent                                 59.4
# contested_catch_rate                            NaN
# contested_receptions                              0
# contested_targets                                 0
# declined_penalties                                0
# drop_rate                                       8.9
# drops                                             8
# first_downs                                       0
# franchise_id                                    266
# fumbles                                           1
# grades_hands_drop                              66.4
# grades_hands_fumble                            58.9
# grades_offense                                 67.6
# grades_pass_block                              63.6
# grades_pass_route                              68.3
# inline_rate                                     1.1
# inline_snaps                                      6
# interceptions                                     3
# longest                                          51
# pass_block_rate                                 0.2
# pass_blocks                                       1
# pass_plays                                      545
# penalties                                         1
# receptions                                       82
# route_rate                                     95.6
# routes                                          521
# slot_rate                                      51.6
# slot_snaps                                      281
# targeted_qb_rating                             74.5
# targets                                         138
# touchdowns                                        2
# wide_rate                                      47.2
# wide_snaps                                      257
# yards                                           899
# yards_after_catch                               484
# yards_after_catch_per_reception                 5.9
# yards_per_reception                            11.0
# yprr                                           1.73
# Name: 8, dtype: object
# year                                       2014
# player                             Tajae Sharpe
# player_id                                 10774
# position                                     WR
# team_name                                 UMASS
# player_game_count                            12
# avg_depth_of_target                        13.6
# avoided_tackles                               3
# caught_percent                             62.5
# contested_catch_rate                        NaN
# contested_receptions                          0
# contested_targets                             0
# declined_penalties                            0
# drop_rate                                   4.5
# drops                                         4
# first_downs                                   0
# franchise_id                                216
# fumbles                                       1
# grades_hands_drop                          83.1
# grades_hands_fumble                        57.8
# grades_offense                             82.9
# grades_pass_block                           NaN
# grades_pass_route                          83.2
# inline_rate                                 0.2
# inline_snaps                                  1
# interceptions                                 5
# longest                                      77
# pass_block_rate                             0.0
# pass_blocks                                   0
# pass_plays                                  538
# penalties                                     1
# receptions                                   85
# route_rate                                 95.4
# routes                                      513
# slot_rate                                  22.3
# slot_snaps                                  120
# targeted_qb_rating                         95.3
# targets                                     136
# touchdowns                                    7
# wide_rate                                  77.5
# wide_snaps                                  417
# yards                                      1281
# yards_after_catch                           418
# yards_after_catch_per_reception             4.9
# yards_per_reception                        15.1
# yprr                                        2.5
# Name: 9, dtype: object
