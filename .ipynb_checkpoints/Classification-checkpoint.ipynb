# %%
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('data/data.csv')
labels = pd.read_csv('data/labels.csv')

# %%
x = data.iloc[:,3:]
y1 = labels['800_yard_season']
y2 = labels['1000_yard_season']

# %%
data
# Out:
#      year              player  player_id  player_game_count  \
# 0    2014        Amari Cooper       9437                 14
# 1    2014        Justin Hardy       9540                 13
# 2    2014         Vince Mayle       9556                 12
# 3    2014         Kevin White       9440                 13
# 4    2014       Jaelen Strong       9503                 12
# ..    ...                 ...        ...                ...
# 372  2022      Cedric Tillman      84434                  6
# 373  2022        Jalen Brooks     111284                 12
# 374  2022      Michael Wilson      84423                  6
# 375  2022    Shedrick Jackson      84136                 12
# 376  2022  Jaxon Smith-Njigba     129758                  3
#
#      avg_depth_of_target  avoided_tackles  caught_percent  drops  \
# 0                    9.9               26            71.3      8
# 1                    9.5               20            72.5      5
# ...

# %%
x_scaled = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x_scaled)

pcaDF = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
explained_variance = pca.explained_variance_ratio_

# %%
pcaDf_label = pd.concat([pcaDF, y1], axis = 1)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

targets = [1,0]
colors = ['r','b']

for target, color in zip(targets,colors):
    indicesToKeep = y1 == target
    ax.scatter(pcaDf_label.loc[indicesToKeep, 'principal component 1']
               , pcaDf_label.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)

# %%
import matplotlib.pyplot as plt

plt.matshow(x.corr())
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
plt.show()

#x.style.format(precision=2).background_gradient(cmap='coolwarm')
