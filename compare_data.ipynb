# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("data/receiving_data.db")
cur = con.cursor()

# %% [markdown]
# After connecting to the receiving_data.db, I query all receiving data from both tables by the Wide Receiver position and then close the connection to the SQL db.

# %%
NFL_wr = pd.read_sql_query("SELECT * from NFL where position == 'WR'", con)
NCAA_wr = pd.read_sql_query("SELECT * from NCAA where position == 'WR'", con)

con.close()

# %%
NFL_sql.head()
# Out:
#    index  year            player  player_id position team_name  \
# 0      0  2015     Antonio Brown       5718       WR       PIT
# 1      1  2015   DeAndre Hopkins       7808       WR       HST
# 2      2  2015       Julio Jones       6158       WR       ATL
# 3      3  2015  Demaryius Thomas       5547       WR       DEN
# 4      4  2015  Brandon Marshall       3064       WR       NYJ
#
#    player_game_count  avg_depth_of_target  avoided_tackles  caught_percent  \
# 0                 17                 11.2               25            70.8
# 1                 17                 14.6                5            59.1
# 2                 16                 10.5               20            70.5
# 3                 19                 10.6               20            59.3
# 4                 16                 12.7               14            65.3
#
#    ...  targeted_qb_rating  targets  touchdowns  wide_rate  wide_snaps  yards  \
# ...
